# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import requests
import json

import os
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup

from IPython.core.display import HTML, display

# %% [markdown]
# #### Lecture 4a - JSONs and APIs
# by Vítek Macháček
# October 25, 2022
#
# ### Contents
#
# * Standardized data representation
# * JSON (+ XMLs)
# * Introduction to Requests (GET vs. POST) and APIs

# %% [markdown]
# ### Goals:
#
# * work with data  online/real-time data
# * acquisition, processing - > results
# * Today introduction and next week a practical example

# %% [markdown]
# ## Microservice architecture
#
# * Foundation of modern software architecture
# * Do one thing and do it well.
#
# ![Microservice architecture schema](./img/microservices.png "Microservice Architecture")

# %% [markdown]
# ## Date exchange formats - JSON, XML
#
# `Language of the internet`
#
# * You can send/receive a message with (almost) any service
# * we need system agnostic data format
# * is ediatable in basic editors
# * More complex than simple tables
# * Highly structured - if you dont follow the rules, you are out
# * Both sides need to understand the structure
# * only data. It does not do anything - no code to be run
# * distributed as text/string (to be precise as `bytes` literals)
# * parsed to objects - easy to work with straight away
# * Can be persisted as special files, or some data streams from APIs.
# * Human readable
# * Hierarchical
# * Can be fetched using standard web APIs
#
# ### Purpose
#
# 1. Communication
#     * All imaginable communication channels
#     * Applications
#
# 2. Storing
#     * self-descriptive
#     * human readable
#     * also in DBs - SQL, MongoDB etc.
#
# 3. Standardization
#     * predictability
#     * cooperation
#     * spillovers from standardization
#
# ### Dimensionality problem
#
# * rich information comes at costs of data complexity
# * to interrelate information, you need to high dimensionality (or A LOT of columns)
# * Strongly object-oriented
#
#
# ### 1D:
# * logs
#
# ### 2D
# * tabular data (like pandas DFs)
# * SQL
#
# ### 3+D:
# #### XML (and HTML)
# * eXtensible Markup Language is a software- and hardware-independent tool for storing and transporting data.
# * Officialy defined at 1998, but its roots are even older.
# * XML was designed to carry data - with focus on what data is
# * HTML was designed to display data - with focus on what data should look like displayed
# * XML tags are not predefined like HTML tags are
# * more verbose than JSON
# * can have comments !actually a really cool in useful feature!
# * used historically as a transaction format in many areas:
#     * Scientific measurements
#     * News information
#     * Wheather measurements
#     * Financial transactions
# * Necessary to use XML parser - for example `BeautifulSoup` or `xmltree`
# * doc`x`, xls`x`, etc. stands for xml
#
#
# ### JSON
# * JavaScript Object Notation
# * REST APIs return JSONs
# * often *.json* files
# * but also used in the web etc.
# * supports standard datatypes - strings, integers, floats, lists
# * No comments
# * More compact, less verbose
# * No closing tags
# * Used EVERYWHERE, BUT [NOT LICENSED FOR EVIL](https://www.json.org/license.html). If you want to do evil stuff, use XML instead.
# * Native in JavaScript and close to native in Python (dictionary)
# * Jupyter Notebooks

# %% [markdown]
# # JSON
#
# * JSON is similar to combination of `dictionaries` (`object` in JSON-terms)  and `lists` (`arrays`) in Python

# %%
teachers = [
    {'name':'Jozef Baruník','titles':['doc.','PhDr.','Ph.D.','Bc.','Mgr.'],'ID':1234,'courses':['JEM005','JEM116','JEM059','JEM061']},
    {'name':'Martin Hronec','titles':['Bc.','Mgr.'],'ID':3421,'courses':['JEM005','JEM207']},
]

courses = {
    "JEM005":{'name':'Advanced Econometrics','ECTS':6,'teachers':[3421,1234]},
    'JEM207':{'name':'Data Processing in Python','ECTS':5,'teachers':[3421]},
    'JEM116':{'name':'Applied Econometrics','ECTS':6,'teachers':[1234]},
    'JEM059':{'name':'Quantitative Finance I.','ECTS':6,'teachers':[1234,5678]},
    'JEM061':{'name':'Quantitative Finance II.','ECTS':6,'teachers':[1234,5678]}
}
jsondata = {'teachers':teachers,'courses':courses}
jsondata
# Out:
# {'teachers': [{'name': 'Jozef Baruník',
#    'titles': ['doc.', 'PhDr.', 'Ph.D.', 'Bc.', 'Mgr.'],
#    'ID': 1234,
#    'courses': ['JEM005', 'JEM116', 'JEM059', 'JEM061']},
#   {'name': 'Martin Hronec',
#    'titles': ['Bc.', 'Mgr.'],
#    'ID': 3421,
#    'courses': ['JEM005', 'JEM207']}],
#  'courses': {'JEM005': {'name': 'Advanced Econometrics',
#    'ECTS': 6,
#    'teachers': [3421, 1234]},
#   'JEM207': {'name': 'Data Processing in Python',
#    'ECTS': 5,
#    'teachers': [3421]},
#   'JEM116': {'name': 'Applied Econometrics', 'ECTS': 6, 'teachers': [1234]},
#   'JEM059': {'name': 'Quantitative Finance I.',
#    'ECTS': 6,
#    'teachers': [1234, 5678]},
#   'JEM061': {'name': 'Quantitative Finance II.',
#    'ECTS': 6,
#    'teachers': [1234, 5678]}}}

# %% [markdown]
# is this a valid JSON?

# %% [markdown]
# https://jsonformatter.curiousconcept.com/

# %%
js = json.dumps(
    jsondata, indent=4, ensure_ascii = False
) #json formatted string!

print(js)
# Out:
# {
#     "teachers": [
#         {
#             "name": "Jozef Baruník",
#             "titles": [
#                 "doc.",
#                 "PhDr.",
#                 "Ph.D.",
#                 "Bc.",
#                 "Mgr."
#             ],
#             "ID": 1234,
#             "courses": [
#                 "JEM005",
#                 "JEM116",
#                 "JEM059",
#                 "JEM061"
#             ]
#         },
#         {
#             "name": "Martin Hronec",
#             "titles": [
#                 "Bc.",
#                 "Mgr."
#             ],
#             "ID": 3421,
#             "courses": [
#                 "JEM005",
#                 "JEM207"
#             ]
#         }
#     ],
#     "courses": {
#         "JEM005": {
#             "name": "Advanced Econometrics",
#             "ECTS": 6,
#             "teachers": [
#                 3421,
#                 1234
#             ]
#         },
#         "JEM207": {
#             "name": "Data Processing in Python",
#             "ECTS": 5,
#             "teachers": [
#                 3421
#             ]
#         },
#         "JEM116": {
#             "name": "Applied Econometrics",
#             "ECTS": 6,
#             "teachers": [
#                 1234
#             ]
#         },
#         "JEM059": {
#             "name": "Quantitative Finance I.",
#             "ECTS": 6,
#             "teachers": [
#                 1234,
#                 5678
#             ]
#         },
#         "JEM061": {
#             "name": "Quantitative Finance II.",
#             "ECTS": 6,
#             "teachers": [
#                 1234,
#                 5678
#             ]
#         }
#     }
# }

# %% [markdown]
# # Reading data using `requests` library
#
# * API = Application Programming Interface
# * more specifically: http based APIs
#
# ### When to use?
# * whenever more applications need to communicate -
#     * DB speaks to app
#     * accounting system communicates with inventory system
#     * Google Maps need to get info about local public transport
#     * ML-based BitCoin price prediction to be used to facilitate automatic trading
#     *
# * user-friendly interface for complicated tasks - DEEP AI, Google Maps
# * Data - Golemio, OpenStreetMaps

# %% [markdown]
# ## HTTP request
#
# * A most standard webserver communication channel around
# * `Client` asks/requests questions - **requests**
# * `Server` replies/serve answers - **responses**
#
# ### HTTP request structure:
# * URL
#     * domain
#     * route
#     * parameters
# * Request Type - GET, POST, PUT, DELETE
# * Request Header
#     * authentication
#     * cookies
#     * other metadata
# * Outcoming data (will see below)
#
# ### HTTP response structure
# * Header
#     * cookies
#     * other metadata - responding server, dates,
# * Status Code:
#     * 200 - success
#     * 404 - resource does not exist
#     * 500 - the server failed during processing your request
# * Content
#     * text - JSON, HTML etc.
#     * file
#
# ### API types
# 1) REST API - use HTTP request and returns JSON
# 2) SOAP API - use HTTP request and returns XML
# 3) Website - use HTTP request and returns set of HTML, JavaScript, CSS and other files
#
#
# ### GET request
# * fast
# * public
# * data flow only one direction
# * parameters via request adress
#
# ### POST request
# * slow
# * private
# * both sides can send data

# %% [markdown]
# ### The simplest request

# %%
import requests

# %%
r = requests.get('https://www.google.com/')
print(r.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="cs"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){window.google={kEI:'51QTZLDbBqmDhbIP5IeB8AM',kEXPI:'0,1359409,6058,207,2414,2390,2316,383,246,5,1129120,1197755,646,171,379918,16115,28684,22430,1362,12316,17583,4998,13228,3847,35735,2709,885,1987,2891,12360,30668,23475,4144,2403,2614,3900,9242,3,346,230,6459,14124,4,1528,2304,42127,13658,4437,9358,7428,5827,2530,4094,7596,1,11942,30212,2,14022,6002,1644,18093,5679,1021,31122,4568,6252,23424,1252,5835,14968,4332,5017,2467,25076,2006,5895,2260,7381,1480,14489,874,6577,13056,7,1922,5784,16410,8976,388,14375,6305,2007,18191,20233,19404,802,1622,1779,4976,1746,2195,4436,6514,2646,1423,280,4135,988,3030,426,848,4837,1410,890,160,2093,487,4665,1804,7553,676,2243,1649,108,993,135,1003,1491,4666,2904,3413,5674,212,2,375,537,2344,736,78,2751,1,1172,1581,699,153,91,613,202,1726,639,662,1252,209,87,84,149,1461,284,1350,4707,223,1418,2826,398,681,755,1159,1821,1030,680,985,5,663,295,1442,279,392,9,230,3,3,375,165,58,408,203,278,46,335,224,23,197,2,147,4,4,26,1,320,635,3,449,412,88,3,412,281,3,481,729,286,1360,319,3,689,628,240,24,80,765,1102,182,20,582,115,93,4,925,1173,1,616,89,5226685,298,5994420,2804423,3311,141,795,19735,1,303,46,4567,16,23945899,553,4041590,1964,16673,2893,512,5738,12561,1539,530,815,105,1415246',kBL:'ZGxm'};google.sn='webhp';google.kHL='cs';})();(function(){
# var f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}
# function n(a,b,c,d,g){var e="";c||-1!==b.search("&ei=")||(e="&ei="+l(d),-1===b.search("&lei=")&&(d=m(d))&&(e+="&lei="+d));d="";!c&&f._cshid&&-1===b.search("&cshid=")&&"slh"!==a&&(d="&cshid="+f._cshid);c=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now()+d;/^http:/i.test(c)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:c,glmm:1}),c="");return c};h=google.kEI;google.getEI=l;google.getLEI=m;google.ml=function(){return null};google.log=function(a,b,c,d,g){if(c=n(a,b,c,d,g)){a=new Image;var e=k.length;k[e]=a;a.onerror=a.onload=a.onabort=function(){delete k[e]};a.src=c}};google.logUrl=n;}).call(this);(function(){google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style><style>body,td,a,p,.h{font-family:arial,sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#1558d6}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px arial,sans-serif}.gsfs{font:17px arial,sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#000}a{color:#4b11a8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#1558d6}a:visited{color:#4b11a8}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#f8f9fa;border:solid 1px;border-color:#dadce0 #70757a #70757a #dadce0;height:30px}.lsbb{display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;border:none;color:#000;cursor:pointer;height:30px;margin:0;outline:0;font:15px arial,sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}.Ucigb{width:458px}</style><script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){window.google.erd={jsr:1,bv:1759,de:true};
# var h=this||self;var k,l=null!=(k=h.mei)?k:1,n,p=null!=(n=h.sdo)?n:!0,q=0,r,t=google.erd,v=t.jsr;google.ml=function(a,b,d,m,e){e=void 0===e?2:e;b&&(r=a&&a.message);if(google.dl)return google.dl(a,e,d),null;if(0>v){window.console&&console.error(a,d);if(-2===v)throw a;b=!1}else b=!a||!a.message||"Error loading script"===a.message||q>=l&&!m?!1:!0;if(!b)return null;q++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(t.jsr)+"&bver="+b(t.bv);var f=a.lineNumber;void 0!==f&&(c+="&line="+f);var g=
# a.fileName;g&&(0<g.indexOf("-extension:/")&&(e=3),c+="&script="+b(g),f&&g===window.location.href&&(f=document.documentElement.outerHTML.split("\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));c+="&jsel="+e;for(var u in d)c+="&",c+=b(u),c+="=",c+=b(d[u]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");12288<=c.length&&(c=c.substr(0,12288));a=c;m||google.log(0,"",a);return a};window.onerror=function(a,b,d,m,e){r!==a&&(a=e instanceof Error?e:Error(a),void 0===d||"lineNumber"in a||(a.lineNumber=d),void 0===b||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,"SyntaxError"===a.name||"SyntaxError"===a.message.substring(0,11)||-1!==a.message.indexOf("Script error")?3:0));r=null;p&&q>=l&&(window.onerror=null)};})();</script></head><body bgcolor="#fff"><script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id=gbar><nobr><b class=gb1>Vyhledávání</b> <a class=gb1 href="https://www.google.cz/imghp?hl=cs&tab=wi">Obrázky</a> <a class=gb1 href="https://maps.google.cz/maps?hl=cs&tab=wl">Mapy</a> <a class=gb1 href="https://play.google.com/?hl=cs&tab=w8">Play</a> <a class=gb1 href="https://www.youtube.com/?tab=w1">YouTube</a> <a class=gb1 href="https://news.google.com/?tab=wn">Zprávy</a> <a class=gb1 href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class=gb1 href="https://drive.google.com/?tab=wo">Disk</a> <a class=gb1 style="text-decoration:none" href="https://www.google.cz/intl/cs/about/products?tab=wh"><u>Dal&#353;í</u> &raquo;</a></nobr></div><div id=guser width=100%><nobr><span id=gbn class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a href="http://www.google.cz/history/optout?hl=cs" class=gb4>Webová historie</a> | <a  href="/preferences?hl=cs" class=gb4>Nastavení</a> | <a target=_top id=gb_70 href="https://accounts.google.com/ServiceLogin?hl=cs&passive=true&continue=https://www.google.com/&ec=GAZAAQ" class=gb4>P&#345;ihlásit</a></nobr></div><div class=gbh style=left:0></div><div class=gbh style=right:0></div></div><center><br clear="all" id="lgpd"><div id="lga"><img alt="Google" height="92" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272" id="hplogo"><br><br></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%">&nbsp;</td><td align="center" nowrap=""><input name="ie" value="ISO-8859-1" type="hidden"><input value="cs" name="hl" type="hidden"><input name="source" type="hidden" value="hp"><input name="biw" type="hidden"><input name="bih" type="hidden"><div class="ds" style="height:32px;margin:4px 0"><div style="position:relative;zoom:1"><input class="lst Ucigb" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#000;padding-right:38px" autocomplete="off" value="" title="Hledat Googlem" maxlength="2048" name="q" size="57"><img src="/textinputassistant/tia.png" style="position:absolute;cursor:pointer;right:5px;top:4px;z-index:300" data-script-url="/textinputassistant/11/cs_tia.js" id="tsuid_1" alt="" height="23" width="27"><script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){var id='tsuid_1';document.getElementById(id).onclick = function(){var s = document.createElement('script');s.src = this.getAttribute('data-script-url');(document.getElementById('xjsc')||document.body).appendChild(s);};})();</script></div></div><br style="line-height:0"><span class="ds"><span class="lsbb"><input class="lsb" value="Hledat Googlem" name="btnG" type="submit"></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid_2" value="Zkusím &#353;t&#283;stí" name="btnI" type="submit"><script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){var id='tsuid_2';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input value="AK50M_UAAAAAZBNi9_gg86u_KB0DM5Q8oVsGen3sL5qE" name="iflsig" type="hidden"></span></span></td><td class="fl sblc" align="left" nowrap="" width="25%"><a href="/advanced_search?hl=cs&amp;authuser=0">Roz&#353;í&#345;ené vyhledávání</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"><script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){var a,b="1";if(document&&document.getElementById)if("undefined"!=typeof XMLHttpRequest)b="2";else if("undefined"!=typeof ActiveXObject){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if("2"==a&&-1==location.search.indexOf("&gbv=2")){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div id="gac_scont"></div><div style="font-size:83%;min-height:3.5em"><br></div><span id="footer"><div style="font-size:10pt"><div style="margin:19px auto;text-align:center" id="WqQANb"><a href="/intl/cs/ads/">Reklama</a><a href="http://www.google.cz/intl/cs/services/">&#344;e&#353;ení pro firmy</a><a href="/intl/cs/about.html">V&#353;e o Googlu</a><a href="https://www.google.com/setprefdomain?prefdom=CZ&amp;prev=https://www.google.cz/&amp;sig=K_QPAFLz-tjPK_lwcMuTLNwK019qo%3D">Google.cz</a></div></div><p style="font-size:8pt;color:#70757a">&copy; 2023 - <a href="/intl/cs/policies/privacy/">Ochrana soukromí</a> - <a href="/intl/cs/policies/terms/">Smluvní podmínky</a></p></span></center><script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}a&&b&&(a!=google.cdo.width||b!=google.cdo.height)&&google.log("","","/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI);}).call(this);})();</script> <script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){google.xjs={ck:'xjs.hp.Y2W3KAJ0Jco.L.X.O',cs:'ACT90oF6fFKP3NqTb-CWr4oWCMrcj1fkdA',excm:[]};})();</script>  <script nonce="4lB95tqE4JpU3YNAPTj5Cg">(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.AcjFwnTLgZA.O/am\x3dAACgEwBAAYAF/d\x3d1/ed\x3d1/rs\x3dACT90oH2zUVxruz8tIwzMmukkUURelbx6g/m\x3dsb_he,d';var amd=0;
# var d=this||self,e=function(a){return a};var g;var l=function(a,b){this.g=b===h?a:""};l.prototype.toString=function(){return this.g+""};var h={};
# function m(){var a=u;google.lx=function(){p(a);google.lx=function(){}};google.bx||google.lx()}
# function p(a){google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");var b=document;var c="SCRIPT";"application/xhtml+xml"===b.contentType&&(c=c.toLowerCase());c=b.createElement(c);c.id="base-js";a=null===a?"null":void 0===a?"undefined":a;if(void 0===g){b=null;var k=d.trustedTypes;if(k&&k.createPolicy){try{b=k.createPolicy("goog#html",{createHTML:e,createScript:e,createScriptURL:e})}catch(q){d.console&&d.console.error(q.message)}g=b}else g=b}a=(b=g)?b.createScriptURL(a):a;a=new l(a,h);c.src=a instanceof l&&a.constructor===l?a.g:"type_error:TrustedResourceUrl";var f,n;(f=(a=null==(n=(f=(c.ownerDocument&&c.ownerDocument.defaultView||window).document).querySelector)?void 0:n.call(f,"script[nonce]"))?a.nonce||a.getAttribute("nonce")||"":"")&&c.setAttribute("nonce",f);document.body.appendChild(c);google.psa=!0};google.xjsu=u;setTimeout(function(){0<amd?google.caft(function(){return m()},amd):m()},0);})();function _DumpException(e){throw e;}
# function _F_installCss(c){}
# (function(){google.jl={blt:'none',chnk:0,dw:false,dwu:true,emtn:0,end:0,ico:false,ikb:0,ine:false,injs:'none',injt:0,injth:0,injv2:false,lls:'default',pdt:0,rep:0,snet:true,strt:0,ubm:false,uwp:true};})();(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22agen\x22:true,\x22cgen\x22:true,\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22ds\x22:\x22\x22,\x22fl\x22:true,\x22host\x22:\x22google.com\x22,\x22jsonp\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22Vymazat vyhledávání\x22,\x22dym\x22:\x22M&#283;li jste na mysli:\x22,\x22lcky\x22:\x22Zkusím &#353;t&#283;stí\x22,\x22lml\x22:\x22Dal&#353;í informace\x22,\x22psrc\x22:\x22Toto vyhledávání bylo odebráno z va&#353;í \\u003Ca href\x3d\\\x22/history\\\x22\\u003EWebové historie\\u003C/a\\u003E\x22,\x22psrl\x22:\x22Odstranit\x22,\x22sbit\x22:\x22Vyhledávání pomocí obrázku\x22,\x22srch\x22:\x22Hledat Googlem\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22rfs\x22:[],\x22sbas\x22:\x220 3px 8px 0 rgba(0,0,0,0.2),0 0 0 1px rgba(0,0,0,0.08)\x22,\x22stok\x22:\x22mFvRkYTnACxVpw8oo-CbVeDgaeQ\x22}}';google.pmc=JSON.parse(pmc);})();</script>       </body></html>

# %% [markdown]
# r = requests.get('https://www.google.com/')
# display(HTML(r.text))

# %% [markdown]
# ## "Real-world" APIs
#
# ### Sreality
#
# * surprisingly no need for authentication
# https://www.sreality.cz/hledani/prodej/byty/praha

# %%
r = requests.get('https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page=20&tms=1678732084920')
r.text
# Out:
# '{"meta_description": "5900 realit v nab\\u00eddce prodej byt\\u016f Praha. Vyberte si novou nemovitost na sreality.cz s hled\\u00e1n\\u00edm na map\\u011b a velk\\u00fdmi n\\u00e1hledy fotografi\\u00ed nab\\u00edzen\\u00fdch byt\\u016f.", "result_size": 5900, "_embedded": {"estates": [{"labelsReleased": [["after_reconstruction", "balcony"], ["post_office"]], "has_panorama": 0, "labels": ["Po rekonstrukci", "Balkon", "Po\\u0161ta 3 min. p\\u011b\\u0161ky"], "is_auction": false, "labelsAll": [["personal", "after_reconstruction", "balcony", "brick", "cellar", "elevator"], ["playground", "sightseeing", "candy_shop", "vet", "small_shop", "theater", "tavern", "movies", "school", "atm", "bus_public_transport", "sports", "shop", "metro", "kindergarten", "restaurant", "medic", "post_office", "drugstore", "train", "tram"]], "seo": {"category_main_cb": 1, "category_sub_cb": 10, "category_type_cb": 1, "locality": "praha-bubenec-"}, "exclusively_at_rk": 0, "category": 1, "has_floor_plan": 1, "_embedded": {"favourite": {"is_favourite": false, "_links": {"self": {"profile": "/favourite/doc", "href": "/cs/v2/favourite/2027628892", "title": "Oblibene inzeraty"}}}, "note": {"note": "", "_links": {"self": {"profile": "/note/doc", "href": "/cs/v2/note/2027628892", "title": "Poznamky inzeratu"}}, "has_note": false}, "company": {"url": "YT-Luxury-Property-luxusni-byty-Praha-Praha-Nove-Mesto", "id": 20710, "name": "Y&T Luxury Property \\u2013 luxusn\\u00ed byty Praha", "logo_small": "https://d48-a.sdn.cz/d_48/c_img_G_I/WK7Fdo.png?fl=res,140,140,3,ffffff"}}, "paid_logo": 1, "locality": "Praha 7 - Bubene\\u010d", "has_video": true, "advert_images_count": 9, "new": false, "auctionPrice": 0.0, "type": 1, "hash_id": 2027628892, "attractive_offer": 0, "price": 23389000, "price_czk": {"value_raw": 23389000, "unit": "", "name": "Celkov\\u00e1 cena"}, "_links": {"dynamicDown": [{"href": "https://d18-a.sdn.cz/d_18/c_img_QO_Kd/8D3QAM.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90"}], "dynamicUp": [{"href": "https://d18-a.sdn.cz/d_18/c_img_QO_Kd/8D3QAM.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90"}], "iterator": {"href": "/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1"}, "self": {"href": "/cs/v2/estates/2027628892?region_tip=2453435"}, "images": [{"href": "https://d18-a.sdn.cz/d_18/c_img_QO_Kd/8D3QAM.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_QR_L0/IxPQBQ.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_QJ_Ja/oMJQf2.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_QP_Km/5SdP3p.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_QQ_LQ/Z0pTA2.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_QK_JV/7bVS66.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}], "image_middle2": [{"href": "https://d18-a.sdn.cz/d_18/c_img_QO_Kd/8D3QAM.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}]}, "rus": false, "name": "Prodej bytu 5+kk 122\\u00a0m\\u00b2 (Podkrovn\\u00ed)", "region_tip": 2453435, "gps": {"lat": 50.09307374105792, "lon": 14.408187258942078}, "has_matterport_url": false}, {"labelsReleased": [["terrace"], []], "has_panorama": 0, "labels": ["Terasa"], "is_auction": false, "labelsAll": [["new_building", "personal", "terrace", "garage"], ["tavern", "playground", "vet", "small_shop", "candy_shop", "theater", "movies", "sightseeing", "drugstore", "shop", "sports", "restaurant", "bus_public_transport", "post_office", "medic", "kindergarten", "tram", "school", "metro", "atm", "train"]], "seo": {"category_main_cb": 1, "category_sub_cb": 4, "category_type_cb": 1, "locality": "praha-troja-nad-vavrouskou"}, "exclusively_at_rk": 1, "category": 1, "has_floor_plan": 0, "_embedded": {"favourite": {"is_favourite": false, "_links": {"self": {"profile": "/favourite/doc", "href": "/cs/v2/favourite/1152308812", "title": "Oblibene  ...

# %%
type(r.json())
# Out:
# dict

# %%
r = requests.get('https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10')
r.text
# Out:
# '{"meta_description": "5900 realit v nab\\u00eddce prodej byt\\u016f Praha. Vyberte si novou nemovitost na sreality.cz s hled\\u00e1n\\u00edm na map\\u011b a velk\\u00fdmi n\\u00e1hledy fotografi\\u00ed nab\\u00edzen\\u00fdch byt\\u016f.", "result_size": 5900, "_embedded": {"estates": [{"labelsReleased": [["after_reconstruction", "balcony", "furnished"], ["shop"]], "has_panorama": 0, "labels": ["Po rekonstrukci", "Balkon", "Vybaven\\u00fd", "Obchod 4 min. p\\u011b\\u0161ky"], "is_auction": false, "labelsAll": [["personal", "after_reconstruction", "balcony", "brick", "elevator", "parking_lots", "furnished"], ["playground", "small_shop", "candy_shop", "vet", "tavern", "theater", "movies", "sightseeing", "restaurant", "atm", "medic", "post_office", "kindergarten", "bus_public_transport", "school", "sports", "train", "shop", "metro", "drugstore", "tram"]], "seo": {"category_main_cb": 1, "category_sub_cb": 11, "category_type_cb": 1, "locality": "praha-vinohrady-"}, "exclusively_at_rk": 0, "category": 1, "has_floor_plan": 1, "_embedded": {"favourite": {"is_favourite": false, "_links": {"self": {"profile": "/favourite/doc", "href": "/cs/v2/favourite/1599015004", "title": "Oblibene inzeraty"}}}, "note": {"note": "", "_links": {"self": {"profile": "/note/doc", "href": "/cs/v2/note/1599015004", "title": "Poznamky inzeratu"}}, "has_note": false}, "company": {"url": "YT-Luxury-Property-luxusni-byty-Praha-Praha-Nove-Mesto", "id": 20710, "name": "Y&T Luxury Property \\u2013 luxusn\\u00ed byty Praha", "logo_small": "https://d48-a.sdn.cz/d_48/c_img_G_I/WK7Fdo.png?fl=res,140,140,3,ffffff"}}, "paid_logo": 1, "locality": "Praha 2 - Vinohrady", "has_video": true, "advert_images_count": 12, "new": false, "auctionPrice": 0.0, "type": 1, "hash_id": 1599015004, "attractive_offer": 0, "price": 52424000, "price_czk": {"value_raw": 52424000, "unit": "", "name": "Celkov\\u00e1 cena"}, "_links": {"dynamicDown": [{"href": "https://d18-a.sdn.cz/d_18/c_img_gT_o/OujCud.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90"}], "dynamicUp": [{"href": "https://d18-a.sdn.cz/d_18/c_img_gT_o/OujCud.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90"}], "iterator": {"href": "/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1"}, "self": {"href": "/cs/v2/estates/1599015004?region_tip=2453435"}, "images": [{"href": "https://d18-a.sdn.cz/d_18/c_img_gT_o/OujCud.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_gZ_o/JMdCv2.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_gT_o/BLZCui.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_gS_n/cNmCtD.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_gV_p/p82Cu1.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}, {"href": "https://d18-a.sdn.cz/d_18/c_img_gS_n/DQNZj2.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}], "image_middle2": [{"href": "https://d18-a.sdn.cz/d_18/c_img_gT_o/OujCud.jpeg?fl=res,400,300,3|shr,,20|jpg,90"}]}, "rus": false, "name": "Prodej bytu 5+1\\u00a0185\\u00a0m\\u00b2", "region_tip": 2453435, "gps": {"lat": 50.067389741057916, "lon": 14.446126258942078}, "has_matterport_url": false}, {"labelsReleased": [["terrace"], []], "has_panorama": 0, "labels": ["Terasa"], "is_auction": false, "labelsAll": [["new_building", "personal", "terrace", "garage"], ["tavern", "playground", "vet", "small_shop", "candy_shop", "theater", "movies", "sightseeing", "drugstore", "shop", "sports", "restaurant", "bus_public_transport", "post_office", "medic", "kindergarten", "tram", "school", "metro", "atm", "train"]], "seo": {"category_main_cb": 1, "category_sub_cb": 4, "category_type_cb": 1, "locality": "praha-troja-nad-vavrouskou"}, "exclusively_at_rk": 1, "category": 1, "has_floor_plan": 0, "_embedded": {"favourite": {"is_favourite": false, "_links": {"self": {"profile": "/favourite/doc", "href": "/cs/v2/favourite/1152308812", "ti ...

# %%
d = r.json()

# %%
d.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %%
pd.json_normalize(d['_embedded']['estates'])
# Out:
#                                        labelsReleased  has_panorama  \
# 0                        [[after_reconstruction], []]             0
# 1   [[after_reconstruction, balcony], [post_office...             0
# 2                   [[after_reconstruction], [metro]]             0
# 3                              [[furnished], [medic]]             0
# 4                                [[balcony], [metro]]             0
# 5                    [[garage, partly_furnished], []]             0
# 6                                      [[loggia], []]             0
# 7                       [[terrace, parking_lots], []]             0
# 8                                [[parking_lots], []]             0
# 9                    [[loggia, partly_furnished], []]             0
# 10  [[collective, panel, partly_furnished], [metro...             0
# 11    [[collective, after_reconstruction, panel], []]             0
# 12                   [[garage], [metro, post_office]]             0
# 13                                           [[], []]             0
# 14                                     [[loggia], []]             0
# 15                                     [[loggia], []]             0
# 16                            [[in_construction], []]             0
# 17                                    [[balcony], []]             0
# 18                                    [[balcony], []]             0
# 19  [[balcony, terrace, parking_lots], [post_office]]             0
# 20                                           [[], []]             0
#
#                                                labels  is_auction  \
# 0                                   [Po rekonstrukci]       False
# 1   [Po rekonstrukci, Balkon, Pošta 444 metrů pěšk...       False
# 2            [Po rekonstrukci, Metro 167 metrů pěšky]       False
# 3                      [Vybavený, Lékař 7 min. pěšky]       False
# 4                        [Balkon, Metro 3 min. pěšky]       False
# 5                          [Garáž, Částečně vybavený]       False
# 6                                            [Lodžie]       False
# 7                                 [Terasa, Parkování]       False
# 8                                         [Parkování]       False
# 9                         [Lodžie, Částečně vybavený]       False
# 10  [Družstevní, Panelová, Částečně vybavený, Metr...       False
# 11            [Družstevní, Po rekonstrukci, Panelová]       False
# 12    [Garáž, Metro 1 min. pěšky, Pošta 4 min. pěšky]       False
# 13                                                 []       False
# 14                                           [Lodžie]       False
# 15                                           [Lodžie]       False
# 16                                      [Ve výstavbě]       False
# 17                                           [Balkon]       False
# 18                                           [Balkon]       False
# 19    [Balkon, Terasa, Parkování, Pošta 3 min. pěšky]       False
# 20                                                 []       False
#
#                                             labelsAll  exclusively_at_rk  \
# 0   [[personal, after_reconstruction, brick, eleva...                  0
# 1   [[personal, after_reconstruction, balcony, cel...                  0
# 2   [[personal, after_reconstruction, brick, cella...                  0
# 3   [[new_building, personal, brick, furnished], [...                  0
# 4   [[personal, balcony, cellar], [playground, sma...                  0
# 5   [[personal, brick, elevator, garage, partly_fu...                  0
# 6   [[personal, loggia, brick, cellar, elevator], ...                  1
# 7   [[personal, terrace, brick, cellar, parking_lo...                  0
# 8   [[personal, brick, cellar, parking_lots], [can...                  0
# 9   [[personal, loggia, elevator, partly_furnished...                  1
# 10  [[collective, panel, cellar, elevator, partly_...                  1
# 11  [[collective, after_reconstruction, panel, cel...                  1
# 12  [[new_building, personal, brick, garage], [sma...                  0
# 13  [[personal, brick, elevator], [playground, vet...                  0
# 14  [[new_building, personal, loggia, brick, cella...                  0
# 15  [[new_building, personal, loggia, brick, cella...                  0
# 16  [[in_construction, personal, brick, cellar, el...                  0
# 17  [[personal, balcony, brick, cellar, elevator],...                  0
# 18  [[personal, balcony, brick, cellar, elevator],...                  0
# 19  [[new_building, personal, balcony, terrace, br...                  0
# 20  [[new_building, personal, brick, cellar, eleva...                  0
#
#     category  has_floor_plan  paid_logo                    locality  ...  \
# 0          1               1          1         Praha 2 - Vinohrady  ...
# 1          1               0          1           Praha 4 - Modřany  ...
# 2          1               0          1           Praha 6 - Dejvice  ...
# 3          1               1          0           Praha 5 - Smíchov  ...
# 4          1               0          1           Praha 6 - Břevnov  ...
# 5          1               0          0       Praha 1 - Staré Město  ...
# 6          1               0          1           Praha 6 - Bubeneč  ...
# 7          1               0          1            Praha 4 - Michle  ...
# 8          1               0          1            Praha 4 - Michle  ...
# 9          1               0          0  Praha 10 - Horní Měcholupy  ...
# 10         1               0          0          Praha 5 - Stodůlky  ...
# 11         1               0          0              Praha 4 - Háje  ...
# 12         1               0          0         Praha 1 - Vinohrady  ...
# 13         1               0          1            Praha 3 - Žižkov  ...
# 14         1               1          0        Praha 10 - Strašnice  ...
# 15         1               1          0        Praha 10 - Strašnice  ...
# 16         1               1          0            Praha 4 - Michle  ...
# 17         1               1          0           Praha 5 - Smíchov  ...
# 18         1               1          0           Praha 5 - Smíchov  ...
# 19         1               0          0  Praha 10 - Dolní Měcholupy  ...
# 20         1               1          0             Praha 7 - Troja  ...
#
#     price_czk.unit  price_czk.name  \
# 0                     Celková cena
# 1                     Celková cena
# 2                     Celková cena
# 3                     Celková cena
# 4                     Celková cena
# 5                     Celková cena
# 6                     Celková cena
# 7                     Celková cena
# 8                     Celková cena
# 9                     Celková cena
# 10                    Celková cena
# 11                    Celková cena
# 12                    Celková cena
# 13                    Celková cena
# 14                    Celková cena
# 15                    Celková cena
# 16                    Celková cena
# 17                    Celková cena
# 18                    Celková cena
# 19                    Celková cena
# 20                    Celková cena
#
#                                    _links.dynamicDown  \
# 0   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 1   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 2   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_...
# 3   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_...
# 4   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_...
# 5   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_...
# 6   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_...
# 7   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_...
# 8   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_...
# 9   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_...
# 10  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 11  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_...
# 12  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_...
# 13  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_...
# 14  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 15  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_...
# 16  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_...
# 17  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_...
# 18  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_...
# 19  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_...
# 20  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_...
#
#                                      _links.dynamicUp  \
# 0   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 1   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 2   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_...
# 3   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_...
# 4   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_...
# 5   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_...
# 6   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_...
# 7   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_...
# 8   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_...
# 9   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_...
# 10  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 11  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_...
# 12  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_...
# 13  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_...
# 14  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 15  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_...
# 16  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_...
# 17  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_...
# 18  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_...
# 19  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_...
# 20  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_...
#
#                                  _links.iterator.href  \
# 0   /cs/v2/estate-iterator/0?category_main_cb=1&su...
# 1   /cs/v2/estate-iterator/1?category_main_cb=1&su...
# 2   /cs/v2/estate-iterator/2?category_main_cb=1&su...
# 3   /cs/v2/estate-iterator/3?category_main_cb=1&su...
# 4   /cs/v2/estate-iterator/4?category_main_cb=1&su...
# 5   /cs/v2/estate-iterator/5?category_main_cb=1&su...
# 6   /cs/v2/estate-iterator/6?category_main_cb=1&su...
# 7   /cs/v2/estate-iterator/7?category_main_cb=1&su...
# 8   /cs/v2/estate-iterator/8?category_main_cb=1&su...
# 9   /cs/v2/estate-iterator/9?category_main_cb=1&su...
# 10  /cs/v2/estate-iterator/10?category_main_cb=1&s...
# 11  /cs/v2/estate-iterator/11?category_main_cb=1&s...
# 12  /cs/v2/estate-iterator/12?category_main_cb=1&s...
# 13  /cs/v2/estate-iterator/13?category_main_cb=1&s...
# 14  /cs/v2/estate-iterator/14?category_main_cb=1&s...
# 15  /cs/v2/estate-iterator/15?category_main_cb=1&s...
# 16  /cs/v2/estate-iterator/16?category_main_cb=1&s...
# 17  /cs/v2/estate-iterator/17?category_main_cb=1&s...
# 18  /cs/v2/estate-iterator/18?category_main_cb=1&s...
# 19  /cs/v2/estate-iterator/19?category_main_cb=1&s...
# 20  /cs/v2/estate-iterator/20?category_main_cb=1&s...
#
#                                 _links.self.href  \
# 0   /cs/v2/estates/3188635468?region_tip=2453444
# 1                       /cs/v2/estates/995072092
# 2                      /cs/v2/estates/3793077324
# 3                      /cs/v2/estates/1261421644
# 4                      /cs/v2/estates/2069570636
# 5                      /cs/v2/estates/1161749580
# 6                      /cs/v2/estates/2268017740
# 7                      /cs/v2/estates/1380680780
# 8                      /cs/v2/estates/1866961996
# 9                       /cs/v2/estates/435889228
# 10                     /cs/v2/estates/3854488652
# 11                      /cs/v2/estates/828618572
# 12                     /cs/v2/estates/4187477836
# 13                     /cs/v2/estates/2184430668
# 14                     /cs/v2/estates/2763445836
# 15                     /cs/v2/estates/2187130444
# 16                     /cs/v2/estates/2954425932
# 17                       /cs/v2/estates/85759564
# 18                     /cs/v2/estates/4234111324
# 19                      /cs/v2/estates/116409932
# 20                     /cs/v2/estates/2932393804
#
#                                         _links.images  \
# 0   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 1   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 2   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_...
# 3   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_...
# 4   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_...
# 5   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_...
# 6   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_...
# 7   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_...
# 8   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_...
# 9   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_...
# 10  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 11  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_...
# 12  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_...
# 13  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_...
# 14  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...
# 15  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_...
# 16  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_...
# 17  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_...
# 18  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_...
# 19  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_...
# 20  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_...
#
#                                  _links.image_middle2    gps.lat    gps.lon
# 0   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...  50.063838  14.449678
# 1   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...  50.005107  14.415520
# 2   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_...  50.089152  14.400874
# 3   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_...  50.059828  14.407885
# 4   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_...  50.073512  14.357976
# 5   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_...  50.071730  14.425545
# 6   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_...  50.092604  14.409296
# 7   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_...  50.037886  14.459388
# 8   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_...  50.037886  14.459388
# 9   [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_...  50.037291  14.554118
# 10  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...  50.034896  14.344050
# 11  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gR_...  50.025618  14.525317
# 12  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_...  50.063838  14.449678
# 13  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_...  50.074786  14.457568
# 14  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_...  50.068934  14.498897
# 15  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_...  50.068774  14.498394
# 16  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_...  50.044615  14.476440
# 17  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_...  50.064181  14.380319
# 18  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_...  50.064181  14.380319
# 19  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_...  50.047343  14.566546
# 20  [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_...  50.107608  14.421708
#
# [21 rows x 50 columns]

# %%
pd.json_normalize(d['_embedded']['estates'])

# %% [markdown]
# ### World Bank

# %% [markdown]
# #### Exploratory request

# %%
d = requests.get('http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&per_page=100').json()

# %%
d[0]
# Out:
# {'page': 1,
#  'pages': 165,
#  'per_page': 100,
#  'total': 16492,
#  'sourceid': '2',
#  'sourcename': 'World Development Indicators',
#  'lastupdated': '2023-03-01'}

# %% [markdown]
# #### Look at the data in the dataframe

# %%
pd.json_normalize(d[1])
# Out:
#    countryiso3code  date      value unit obs_status  decimal indicator.id  \
# 0              AFE  2021  702976832                        0  SP.POP.TOTL
# 1              AFE  2020  685112705                        0  SP.POP.TOTL
# 2              AFE  2019  667242712                        0  SP.POP.TOTL
# 3              AFE  2018  649756874                        0  SP.POP.TOTL
# 4              AFE  2017  632746296                        0  SP.POP.TOTL
# ..             ...   ...        ...  ...        ...      ...          ...
# 95             AFW  1988  195969722                        0  SP.POP.TOTL
# 96             AFW  1987  190759952                        0  SP.POP.TOTL
# 97             AFW  1986  185720244                        0  SP.POP.TOTL
# 98             AFW  1985  180817312                        0  SP.POP.TOTL
# 99             AFW  1984  176054495                        0  SP.POP.TOTL
#
#       indicator.value country.id                country.value
# 0   Population, total         ZH  Africa Eastern and Southern
# 1   Population, total         ZH  Africa Eastern and Southern
# 2   Population, total         ZH  Africa Eastern and Southern
# 3   Population, total         ZH  Africa Eastern and Southern
# 4   Population, total         ZH  Africa Eastern and Southern
# ..                ...        ...                          ...
# 95  Population, total         ZI   Africa Western and Central
# 96  Population, total         ZI   Africa Western and Central
# 97  Population, total         ZI   Africa Western and Central
# 98  Population, total         ZI   Africa Western and Central
# 99  Population, total         ZI   Africa Western and Central
#
# [100 rows x 10 columns]

# %% [markdown]
# ### More advanced example: Paging
#
# #### Return to Python basics 1: Errors and exceptions in Python

# %%
for i in range(-5,5):
    print(5/i)
# Out:
# -1.0
# -1.25
# -1.6666666666666667
# -2.5
# -5.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[49], line 2
#       1 for i in range(-5,5):
# ----> 2     print(5/i)
#
# ZeroDivisionError: division by zero

# %%
for i in range(-5,5):
    try:
        print(1/i)
    except:
        print(f'dividing with {i} raised an error. Are you sure your input was correct?')
# Out:
# -0.2
# -0.25
# -0.3333333333333333
# -0.5
# -1.0
# dividing with 0 raised an error. Are you sure your input was correct?
# 1.0
# 0.5
# 0.3333333333333333
# 0.25

# %% [markdown]
# Return to Python basics 2: Formatting strings

# %%
my_name = 'Vítek'

f'Hello {my_name}!'

# %%
string_template = 'Today {teachers_name} is teaching and he is in the {teachers_mood} mood'

string_template.format(
    teachers_name='Vítek',
    teachers_mood='good'
)

# %% [markdown]
# Sending API requests is always risky - you do not control the other side of the transaction
#
# Try listing first ten pages of results in the request
#
# Always check if everything goes fine by checking the request status code

# %%
l = []
url_template = 'http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&page={page_num}'

for i in range(1,10):
    r = requests.get(url_template.format(page_num=i))    
    if r.ok: #r.status_code == 200 would also work!
        l.append(r.json())

# %% [markdown]
# OK, but you still have imply a strong confidence on the other side, try and except is more certain

# %%
l = []
url_template = 'http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&page={page_num}'

for i in range(1,10):
    url = url_template.format(page_num=i)
    try:
        r = requests.get(url)    
        if r.ok: #r.status_code == 200 would also work!
            l.append(r.json())
    except:
        print(f'At least I want to know that something went wrong and when. Url: {url}')

# %% [markdown]
# OMG, this looks a bit messy. I would consider a writing function to increase clarity

# %%
def request_worldbank(url):
    try:
        r = requests.get(url)    
        if r.ok: #r.status_code == 200 would also work!
            return r.json()
        else:
            print(f'The url request on {url} not succesful. Status code: {r.status_code}. Message: {r.message}')
    except:
        print(f'At least I want to know that something went wrong and when. Url: {url}')

l = []
url_template = 'http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&page={page_num}'
for i in range(1,10):
    l.append(request_worldbank(url_template.format(page_num=i)))

# %%
l = [request_worldbank(url_template.format(page_num=i)) for i in range(1,10)]

pd.concat([pd.json_normalize(output_json[1]) for output_json in l])

# %%
def download_worldbank(indicator):
    url_template = 'http://api.worldbank.org/v2/country/all/indicator/{indicator}?format=json&page={page}&per_page=500'
    first_request = requests.get(url_template.format(indicator=indicator,page=1)).json()
        
    pages = first_request[0]['pages']
    
    def single_worldbank_request(url):
        try:
            r = requests.get(url)
            if r.ok:
                return pd.json_normalize(r.json()[1])
        except Exception as e:
            print(f'Could not parse an URL {url}. Read the message: {e.msg}')
    
    first_data = pd.json_normalize(first_request[1])
    
    l = [single_worldbank_request(url_template.format(indicator=indicator,page=page)) for page in range(2,pages+1)]

    return pd.concat([first_data] + l).set_index(['countryiso3code','date']).value
        
population = download_worldbank('SP.POP.TOTL')
population

# %% [markdown]
# ### Eurostat

# %%
from io import StringIO
r_gdp = requests.get('https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/NAMA_10_GDP?format=SDMX-CSV')
gdp = pd.read_csv(StringIO(r_gdp.text))
gdp

# %%
gdp.unit.unique()

# %%
gdp.na_item.unique()

# %%
geo

# %%
gdp['freq'].unique()

# %% [markdown]
# ### Twitter

# %% [markdown]
# ### Scopus

# %%
from secret import SCOPUS_API_KEY
r = requests.get('https://api.elsevier.com/content/search/scopus?query=AUTH(baruník, j.)  ',headers={'Accept':'application/json','X-ELS-APIKey': SCOPUS_API_KEY})

pd.json_normalize(r.json()['search-results']['entry'])

# %% [markdown]
# ### XML or even HTML data

# %%
response = requests.get('https://en.wikipedia.org/wiki/Charles_University')
soup = BeautifulSoup(response.text)
div = soup.find('div',{'id':'mw-content-text'}) #  #mw-content-text > div > p:nth-child(10)texts)
article = ' '.join([p.text for p in div.find_all('p')])
print(article)

# %% [markdown]
# # Bonus example:
#
# <img src="http://ies.fsv.cuni.cz/default/file/get/id/31996" height="500" width="300">

# %% [markdown]
# Will not work without authentication.
#
# * You will need IAM account for Amazon Web Service
# * For that you can create `AWS_ACCESS_KEY` and `AWS_SECRET_KEY`. See here: https://aws.amazon.com/premiumsupport/knowledge-center/create-access-key/
# * create `secret.py` file and put `AWS_ACCESS_KEY` and `AWS_SECRET_KEY`. Follow the template of `secret-example.py`

# %%
# !pip install boto3

# %%
import boto3

# %%
from secret import AWS_ACCESS_KEY, AWS_SECRET_KEY

client=boto3.client('rekognition', 
                    region_name='us-west-2',
                    aws_access_key_id=AWS_ACCESS_KEY,
                    aws_secret_access_key=AWS_SECRET_KEY
)

with open('./img/iespic.jpeg','rb') as f:
    response = client.recognize_celebrities(Image={'Bytes': f.read()})
pd.DataFrame(response['UnrecognizedFaces'][0]['Emotions']).set_index('Type').Confidence.plot.bar()

# %%
response
