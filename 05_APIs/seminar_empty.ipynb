# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Seminar - APIs and real-life coding

# %% [markdown]
# ## Task 1: Requesting API
# ### 1a. Create a function requesting data from sreality
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# * function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - `{'Praha':10,'Brno':14}`
#     * `page` parameter
# * use string inputs for `category_main_cb` and `category_type_cb`
# * test the validity of inputs
# * include try/except clause to handle errors
# * function should return JSON data in python types
# * do not forget to sleep each request at least 0.5s

# %%
import requests
import time

def request_sreality_data(category_main, category_type, locality_region, page):
    category_main_cb = {'flat': 1, 'house': 2, 'land': 3}
    category_type_cb = {'sell': 1, 'rent': 2}
    locality_region_id = {'Praha': 10, 'Brno': 14}

    if category_main not in category_main_cb:
        raise ValueError("Invalid category_main value. Valid options are 'flat', 'house', and 'land'.")

    if category_type not in category_type_cb:
        raise ValueError("Invalid category_type value. Valid options are 'sell' and 'rent'.")

    if locality_region not in locality_region_id:
        raise ValueError("Invalid locality_region value. Valid options are 'Praha' and 'Brno'.")

    base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={}&category_type_cb={}&locality_region_id={}&per_page=60&page={}'.format(
        category_main_cb[category_main], category_type_cb[category_type], locality_region_id[locality_region], page
    )

    try:
        time.sleep(0.5)
        r = requests.get(base_url)
        r.raise_for_status()
        data = r.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"An error occurred while making the request: {e}")
        return None

# Example usage:
data = request_sreality_data('flat', 'sell', 'Praha', 1)
print(data)
# Out:
# {'meta_description': '5836 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.', 'result_size': 5836, '_embedded': {'estates': [{'labelsReleased': [[], []], 'has_panorama': 0, 'labels': [], 'is_auction': False, 'labelsAll': [['new_building', 'personal', 'balcony', 'terrace', 'cellar', 'elevator', 'garage'], ['playground', 'small_shop', 'candy_shop', 'vet', 'tavern', 'theater', 'movies', 'natural_attraction', 'sightseeing', 'drugstore', 'tram', 'bus_public_transport', 'school', 'sports', 'medic', 'shop', 'atm', 'kindergarten', 'restaurant', 'post_office', 'train', 'metro']], 'seo': {'category_main_cb': 1, 'category_sub_cb': 8, 'category_type_cb': 1, 'locality': 'praha-smichov-na-hrebenkach'}, 'exclusively_at_rk': 0, 'category': 1, 'has_floor_plan': 1, '_embedded': {'favourite': {'is_favourite': False, '_links': {'self': {'profile': '/favourite/doc', 'href': '/cs/v2/favourite/3389986636', 'title': 'Oblibene inzeraty'}}}, 'note': {'note': '', '_links': {'self': {'profile': '/note/doc', 'href': '/cs/v2/note/3389986636', 'title': 'Poznamky inzeratu'}}, 'has_note': False}, 'company': {'url': 'YT-Luxury-Property-luxusni-byty-Praha-Praha-Nove-Mesto', 'id': 20710, 'name': 'Y&T Luxury Property – luxusní byty Praha', 'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_I/WK7Fdo.png?fl=res,140,140,3,ffffff'}}, 'paid_logo': 1, 'locality': 'Praha 5 - Smíchov', 'has_video': False, 'advert_images_count': 12, 'new': False, 'auctionPrice': 0.0, 'type': 1, 'hash_id': 3389986636, 'attractive_offer': 0, 'price': 0, 'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'}, '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_p/eJUBCjJ.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}], 'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_p/eJUBCjJ.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}], 'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'}, 'self': {'href': '/cs/v2/estates/3389986636?region_tip=2453450'}, 'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_p/eJUBCjJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}, {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kq/qiAqye.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}, {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_JZ/0ogqvc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}, {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Ja/g9kqu6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}, {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LU/VwDq1W.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}, {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jv/lzEqwe.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}], 'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gY_p/eJUBCjJ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]}, 'rus': False, 'name': 'Prodej bytu 4+kk 124\xa0m²', 'region_tip': 2453450, 'gps': {'lat': 50.06695958339895, 'lon': 14.400748416601054}, 'has_matterport_url': False}, {'labelsReleased': [[], []], 'has_panorama': 0, 'labels': [], 'is_auction': False, 'labelsAll': [['personal', 'brick', 'cellar', 'elevator', 'partly_furnished'], ['playground', 'candy_shop', 'vet', 'small_shop', 'theater', 'tavern', 'movies', 'sightseeing', 'natural_attraction', 'atm', 'restaurant', 'post_office', 'medic', 'tram', 'shop', 'kindergarten', 'drugstore', 'sports', 'metro', 'bus_public_transport', 'train', 'school']], 'seo': {'category_main_cb': 1, 'category_sub_cb': 4, 'category_type_cb': 1, 'locality': 'praha-smichov-u-nikolajky'}, 'exclusively_at_rk': 0, 'category': 1, 'has_floor_plan': 0, '_embedded': {'favourite': {'is_favourite': False, '_links': {'self': {'profile': '/favourite/doc', 'href': '/cs/v2/favourite/934945868', 'title': 'Oblibene inzeraty'}}}, 'note': {'note': '', '_links': {'self': {'profile': '/note/doc', 'href': '/cs/v2/note/934945868', 'title': 'Poznamky inzeratu'}}, 'has_note': False}}, 'paid_logo': 0, 'locali ...

# %%
def request_sreality(page, category_main='flat', category_type='sell', locality_region='Praha'):
    
    time.sleep(0.5)

    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    region_mapping = {'Praha':10, 'Brno':14}
    
    if category_main not in category_mains:
        raise Exception(f'Unknown category main {category_main}')
    
    if category_type not in category_types:
        raise Exception(f'Unknown category type {category_type}')
    
    if locality_region not in region_mapping:
        raise Exception(f'Unknown locality region {locality_region}')
    
    url_template = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main_cb}&category_type_cb={category_type_cb}&locality_region_id={locality_region_id}&per_page60&page={page}'
    
    try:
        url = url_template.format(
            category_main_cb=category_mains[category_main],
            category_type_cb=category_types[category_type],
            locality_region_id=region_mapping[locality_region],
            page=page
        )

        r = requests.get(url)

        return r.json()
    except Exception as e:
        print(e)
d = request_sreality(0)
d.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %%
import requests
import time

def request_sreality_data(category_main_cb, category_type_cb, locality_region_id, page):
    # check validity of inputs
    valid_categories = {'flat':1, 'house':2, 'land':3}
    valid_types = {'sell':1, 'rent':2}
    valid_regions = {'Praha':10, 'Brno':14}
    if category_main_cb not in valid_categories:
        raise ValueError(f"Invalid category_main_cb '{category_main_cb}'. Valid options are {valid_categories.keys()}")
    if category_type_cb not in valid_types:
        raise ValueError(f"Invalid category_type_cb '{category_type_cb}'. Valid options are {valid_types.keys()}")
    if locality_region_id not in valid_regions:
        raise ValueError(f"Invalid locality_region_id '{locality_region_id}'. Valid options are {valid_regions.keys()}")
    
    # make request and handle errors
    base_url = f'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={valid_categories[category_main_cb]}&category_type_cb={valid_types[category_type_cb]}&locality_region_id={valid_regions[locality_region_id]}&per_page=60&page={page}'
    try:
        r = requests.get(base_url)
        r.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return None
    
    # sleep for at least 0.5 seconds between requests
    time.sleep(0.5)
    
    # return JSON data
    return r.json()

# %%
d=request_sreality_data('flat','sell','Praha',0)
d.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
def sreality_json_to_df(sreality_data):
    return pd.DataFrame(sreality_data['_embedded']['estates'])
sreality_json_to_df(d)
# Out:
#                        labelsReleased  has_panorama                    labels  \
# 0                            [[], []]             0                        []
# 1                            [[], []]             0                        []
# 2                            [[], []]             0                        []
# 3                   [[furnished], []]             0                [Vybavený]
# 4               [[not_furnished], []]             0              [Nevybavený]
# ..                                ...           ...                       ...
# 56                           [[], []]             0                        []
# 57  [[collective, not_furnished], []]             0  [Družstevní, Nevybavený]
# 58                           [[], []]             0                        []
# 59              [[not_furnished], []]             0              [Nevybavený]
# 60                           [[], []]             0                        []
#
#     is_auction                                          labelsAll  \
# 0        False  [[personal, after_reconstruction, balcony, bri...
# 1        False  [[personal, panel, elevator], [playground, nat...
# 2        False  [[new_building, personal, terrace, brick, cell...
# 3        False  [[personal, after_reconstruction, brick, eleva...
# 4        False  [[personal, after_reconstruction, brick, cella...
# ..         ...                                                ...
# 56       False  [[new_building, personal, balcony, brick, cell...
# 57       False  [[collective, panel, elevator, not_furnished],...
# 58       False  [[personal, loggia, brick, cellar, elevator, g...
# 59       False  [[personal, panel, not_furnished], [playground...
# 60       False  [[personal, parking_lots, partly_furnished], [...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 10,...                  0
# 1   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 2   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 3   {'category_main_cb': 1, 'category_sub_cb': 10,...                  1
# 4   {'category_main_cb': 1, 'category_sub_cb': 3, ...                  0
# ..                                                ...                ...
# 56  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 57  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 58  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 59  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 60  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
#
#     category  has_floor_plan  \
# 0          1               1
# 1          1               0
# 2          1               1
# 3          1               1
# 4          1               0
# ..       ...             ...
# 56         1               1
# 57         1               1
# 58         1               1
# 59         1               1
# 60         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  2027628892
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  2592592972
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  2891884364
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  2505213004
# 4   {'favourite': {'is_favourite': False, '_links'...  ...   544741196
# ..                                                ...  ...         ...
# 56  {'favourite': {'is_favourite': False, '_links'...  ...   684078156
# 57  {'favourite': {'is_favourite': False, '_links'...  ...   281707596
# 58  {'favourite': {'is_favourite': False, '_links'...  ...  3236873292
# 59  {'favourite': {'is_favourite': False, '_links'...  ...  3480339532
# 60  {'favourite': {'is_favourite': False, '_links'...  ...   167519308
#
#    attractive_offer     price  \
# 0                 0  29149000
# 1                 0   3769000
# 2                 0   5719000
# 3                 0         0
# 4                 0   4271000
# ..              ...       ...
# 56                0   9047000
# 57                0   5528000
# 58                0  13971000
# 59                0   4171000
# 60                0   3617000
#
#                                             price_czk  \
# 0   {'value_raw': 29149000, 'unit': '', 'name': 'C...
# 1   {'value_raw': 3769000, 'unit': '', 'name': 'Ce...
# 2   {'value_raw': 5719000, 'unit': '', 'name': 'Ce...
# 3   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 4   {'value_raw': 4271000, 'unit': '', 'name': 'Ce...
# ..                                                ...
# 56  {'value_raw': 9047000, 'unit': '', 'name': 'Ce...
# 57  {'value_raw': 5528000, 'unit': '', 'name': 'Ce...
# 58  {'value_raw': 13971000, 'unit': '', 'name': 'C...
# 59  {'value_raw': 4171000, 'unit': '', 'name': 'Ce...
# 60  {'value_raw': 3617000, 'unit': '', 'name': 'Ce...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# ..                                                ...    ...
# 56  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 57  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 58  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 59  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 60  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                    name  region_tip  \
# 0   Prodej bytu 5+kk 152 m² (Podkrovní)     2453450
# 1                Prodej bytu 1+kk 27 m²           0
# 2                Prodej bytu 2+kk 41 m²           0
# 3               Prodej bytu 5+kk 162 m²           0
# 4                 Prodej bytu 1+1 37 m²           0
# ..                                  ...         ...
# 56               Prodej bytu 2+kk 56 m²           0
# 57                Prodej bytu 3+1 67 m²           0
# 58               Prodej bytu 3+1 117 m²           0
# 59               Prodej bytu 2+kk 42 m²           0
# 60               Prodej bytu 1+kk 29 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.09108758339895, 'lon': 14.410173416...               False
# 1   {'lat': 50.11257558339895, 'lon': 14.499960416...               False
# 2   {'lat': 50.01912358339895, 'lon': 14.617164416...               False
# 3   {'lat': 50.06036758339895, 'lon': 14.468755416...                True
# 4   {'lat': 50.03628958339895, 'lon': 14.418009416...               False
# ..                                                ...                 ...
# 56  {'lat': 50.04055458339895, 'lon': 14.341896416...               False
# 57  {'lat': 50.07931958339895, 'lon': 14.499312416...                True
# 58  {'lat': 50.060169583398945, 'lon': 14.35936741...               False
# 59  {'lat': 50.07983458339895, 'lon': 14.318833416...                True
# 60  {'lat': 50.04613558339895, 'lon': 14.453542416...               False
#
# [61 rows x 27 columns]

# %%
import pandas as pd

def json_to_dataframe(json_data):
    df = pd.DataFrame(json_data['_embedded']['estates'])
    return df

# %%
json_to_dataframe(data)
# Out:
#         labelsReleased  has_panorama                labels  is_auction  \
# 0   [[collective], []]             0          [Družstevní]       False
# 1             [[], []]             0                    []       False
# 2             [[], []]             0                    []       False
# 3             [[], []]             0                    []       False
# 4             [[], []]             0                    []       False
# ..                 ...           ...                   ...         ...
# 56            [[], []]             0                    []       False
# 57            [[], []]             0                    []       False
# 58            [[], []]             0                    []       False
# 59       [[], [medic]]             0  [Lékař 5 min. pěšky]       False
# 60            [[], []]             0                    []       False
#
#                                             labelsAll  \
# 0   [[collective, loggia, panel, cellar, elevator,...
# 1   [[personal, brick, cellar, parking_lots, not_f...
# 2   [[personal, after_reconstruction, brick, eleva...
# 3   [[personal, after_reconstruction, balcony, bri...
# 4   [[personal, after_reconstruction, brick, eleva...
# ..                                                ...
# 56  [[personal, balcony, loggia, brick, cellar, el...
# 57  [[personal, loggia, panel, cellar, elevator, n...
# 58  [[personal, loggia, brick, cellar, not_furnish...
# 59  [[new_building, personal, balcony, brick, cell...
# 60  [[personal, balcony, loggia, elevator, parking...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 1   {'category_main_cb': 1, 'category_sub_cb': 9, ...                  1
# 2   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 3   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 4   {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# ..                                                ...                ...
# 56  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 57  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# 58  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 59  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 60  {'category_main_cb': 1, 'category_sub_cb': 16,...                  0
#
#     category  has_floor_plan  \
# 0          1               0
# 1          1               1
# 2          1               1
# 3          1               1
# 4          1               1
# ..       ...             ...
# 56         1               1
# 57         1               1
# 58         1               1
# 59         1               1
# 60         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  3036361804
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  2355541580
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  3270218828
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  2917897292
# 4   {'favourite': {'is_favourite': False, '_links'...  ...  3706426444
# ..                                                ...  ...         ...
# 56  {'favourite': {'is_favourite': False, '_links'...  ...   506103628
# 57  {'favourite': {'is_favourite': False, '_links'...  ...  1941210700
# 58  {'favourite': {'is_favourite': False, '_links'...  ...  1944839244
# 59  {'favourite': {'is_favourite': False, '_links'...  ...  2688874316
# 60  {'favourite': {'is_favourite': False, '_links'...  ...  3973945164
#
#    attractive_offer     price  \
# 0                 0   6179000
# 1                 0  18669000
# 2                 0         0
# 3                 0         0
# 4                 0         0
# ..              ...       ...
# 56                0  20480000
# 57                0   7760000
# 58                0  10778000
# 59                0  10707000
# 60                0  32624000
#
#                                             price_czk  \
# 0   {'value_raw': 6179000, 'unit': '', 'name': 'Ce...
# 1   {'value_raw': 18669000, 'unit': '', 'name': 'C...
# 2   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 3   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 4   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# ..                                                ...
# 56  {'value_raw': 20480000, 'unit': '', 'name': 'C...
# 57  {'value_raw': 7760000, 'unit': '', 'name': 'Ce...
# 58  {'value_raw': 10778000, 'unit': '', 'name': 'C...
# 59  {'value_raw': 10707000, 'unit': '', 'name': 'C...
# 60  {'value_raw': 32624000, 'unit': '', 'name': 'C...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# ..                                                ...    ...
# 56  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 57  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 58  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 59  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 60  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                 name  region_tip  \
# 0             Prodej bytu 2+kk 80 m²     2447873
# 1   Prodej bytu 4+1 179 m² (Mezonet)           0
# 2             Prodej bytu 2+kk 67 m²           0
# 3             Prodej bytu 3+1 139 m²           0
# 4              Prodej bytu 2+1 91 m²           0
# ..                               ...         ...
# 56           Prodej bytu 4+kk 186 m²           0
# 57             Prodej bytu 2+1 79 m²           0
# 58            Prodej bytu 3+1 123 m²           0
# 59            Prodej bytu 2+kk 71 m²           0
# 60       Prodej bytu atypické 189 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 49.998739069203815, 'lon': 14.43395993...               False
# 1   {'lat': 50.02736106920381, 'lon': 14.435021930...               False
# 2   {'lat': 50.05026806920381, 'lon': 14.424481930...               False
# 3   {'lat': 50.05026806920381, 'lon': 14.424481930...               False
# 4   {'lat': 50.05026806920381, 'lon': 14.424481930...               False
# ..                                                ...                 ...
# 56  {'lat': 50.09045206920381, 'lon': 14.408879930...               False
# 57  {'lat': 50.039648069203814, 'lon': 14.52572493...               False
# 58  {'lat': 50.04655606920381, 'lon': 14.514462930...               False
# 59  {'lat': 50.09342806920381, 'lon': 14.489923930...               False
# 60  {'lat': 50.085073069203816, 'lon': 14.43185593...               False
#
# [61 rows x 27 columns]

# %%
def sreality_json_to_df(sreality_data):
    return pd.DataFrame(sreality_data['_embedded']['estates'])

sreality_json_to_df(d)
# Out:
#                        labelsReleased  has_panorama                    labels  \
# 0                            [[], []]             0                        []
# 1                            [[], []]             0                        []
# 2                            [[], []]             0                        []
# 3                   [[furnished], []]             0                [Vybavený]
# 4               [[not_furnished], []]             0              [Nevybavený]
# ..                                ...           ...                       ...
# 56                           [[], []]             0                        []
# 57  [[collective, not_furnished], []]             0  [Družstevní, Nevybavený]
# 58                           [[], []]             0                        []
# 59              [[not_furnished], []]             0              [Nevybavený]
# 60                           [[], []]             0                        []
#
#     is_auction                                          labelsAll  \
# 0        False  [[personal, after_reconstruction, balcony, bri...
# 1        False  [[personal, panel, elevator], [playground, nat...
# 2        False  [[new_building, personal, terrace, brick, cell...
# 3        False  [[personal, after_reconstruction, brick, eleva...
# 4        False  [[personal, after_reconstruction, brick, cella...
# ..         ...                                                ...
# 56       False  [[new_building, personal, balcony, brick, cell...
# 57       False  [[collective, panel, elevator, not_furnished],...
# 58       False  [[personal, loggia, brick, cellar, elevator, g...
# 59       False  [[personal, panel, not_furnished], [playground...
# 60       False  [[personal, parking_lots, partly_furnished], [...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 10,...                  0
# 1   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 2   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 3   {'category_main_cb': 1, 'category_sub_cb': 10,...                  1
# 4   {'category_main_cb': 1, 'category_sub_cb': 3, ...                  0
# ..                                                ...                ...
# 56  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 57  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 58  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 59  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 60  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
#
#     category  has_floor_plan  \
# 0          1               1
# 1          1               0
# 2          1               1
# 3          1               1
# 4          1               0
# ..       ...             ...
# 56         1               1
# 57         1               1
# 58         1               1
# 59         1               1
# 60         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  2027628892
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  2592592972
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  2891884364
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  2505213004
# 4   {'favourite': {'is_favourite': False, '_links'...  ...   544741196
# ..                                                ...  ...         ...
# 56  {'favourite': {'is_favourite': False, '_links'...  ...   684078156
# 57  {'favourite': {'is_favourite': False, '_links'...  ...   281707596
# 58  {'favourite': {'is_favourite': False, '_links'...  ...  3236873292
# 59  {'favourite': {'is_favourite': False, '_links'...  ...  3480339532
# 60  {'favourite': {'is_favourite': False, '_links'...  ...   167519308
#
#    attractive_offer     price  \
# 0                 0  29149000
# 1                 0   3769000
# 2                 0   5719000
# 3                 0         0
# 4                 0   4271000
# ..              ...       ...
# 56                0   9047000
# 57                0   5528000
# 58                0  13971000
# 59                0   4171000
# 60                0   3617000
#
#                                             price_czk  \
# 0   {'value_raw': 29149000, 'unit': '', 'name': 'C...
# 1   {'value_raw': 3769000, 'unit': '', 'name': 'Ce...
# 2   {'value_raw': 5719000, 'unit': '', 'name': 'Ce...
# 3   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 4   {'value_raw': 4271000, 'unit': '', 'name': 'Ce...
# ..                                                ...
# 56  {'value_raw': 9047000, 'unit': '', 'name': 'Ce...
# 57  {'value_raw': 5528000, 'unit': '', 'name': 'Ce...
# 58  {'value_raw': 13971000, 'unit': '', 'name': 'C...
# 59  {'value_raw': 4171000, 'unit': '', 'name': 'Ce...
# 60  {'value_raw': 3617000, 'unit': '', 'name': 'Ce...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# ..                                                ...    ...
# 56  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 57  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 58  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 59  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 60  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                    name  region_tip  \
# 0   Prodej bytu 5+kk 152 m² (Podkrovní)     2453450
# 1                Prodej bytu 1+kk 27 m²           0
# 2                Prodej bytu 2+kk 41 m²           0
# 3               Prodej bytu 5+kk 162 m²           0
# 4                 Prodej bytu 1+1 37 m²           0
# ..                                  ...         ...
# 56               Prodej bytu 2+kk 56 m²           0
# 57                Prodej bytu 3+1 67 m²           0
# 58               Prodej bytu 3+1 117 m²           0
# 59               Prodej bytu 2+kk 42 m²           0
# 60               Prodej bytu 1+kk 29 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.09108758339895, 'lon': 14.410173416...               False
# 1   {'lat': 50.11257558339895, 'lon': 14.499960416...               False
# 2   {'lat': 50.01912358339895, 'lon': 14.617164416...               False
# 3   {'lat': 50.06036758339895, 'lon': 14.468755416...                True
# 4   {'lat': 50.03628958339895, 'lon': 14.418009416...               False
# ..                                                ...                 ...
# 56  {'lat': 50.04055458339895, 'lon': 14.341896416...               False
# 57  {'lat': 50.07931958339895, 'lon': 14.499312416...                True
# 58  {'lat': 50.060169583398945, 'lon': 14.35936741...               False
# 59  {'lat': 50.07983458339895, 'lon': 14.318833416...                True
# 60  {'lat': 50.04613558339895, 'lon': 14.453542416...               False
#
# [61 rows x 27 columns]

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
import requests
import pandas as pd
import time

def request_sreality(page, category_main='flat', category_type='sell', locality_region='Praha'):

    time.sleep(0.5)

    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    region_mapping = {'Praha':10, 'Brno':14}

    if category_main not in category_mains:
        raise Exception(f'Unknown category main {category_main}')
    
    if category_type not in category_types:
        raise Exception(f'Unknown category type {category_type}')
    
    if locality_region not in region_mapping:
        raise Exception(f'Unknown locality region {locality_region}')
    
    url_template = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main_cb}&category_type_cb={category_type_cb}&locality_region_id={locality_region_id}&per_page60&page={page}'
     
    try:
        url = url_template.format(
            category_main_cb=category_mains[category_main],
            category_type_cb=category_types[category_type],
            locality_region_id=region_mapping[locality_region],
            page=page
        )

        r=requests.get(url)

        return sreality_json_to_df(r.json())
# Out:
#         labelsReleased  has_panorama                 labels  is_auction  \
# 0             [[], []]             0                     []       False
# 1             [[], []]             0                     []       False
# 2             [[], []]             0                     []       False
# 3        [[], [train]]             0  [Vlak 86 metrů pěšky]       False
# 4   [[collective], []]             0           [Družstevní]       False
# ..                 ...           ...                    ...         ...
# 56            [[], []]             0                     []       False
# 57            [[], []]             0                     []       False
# 58            [[], []]             0                     []       False
# 59            [[], []]             0                     []       False
# 60            [[], []]             0                     []       False
#
#                                             labelsAll  \
# 0   [[new_building, personal, balcony, cellar, ele...
# 1   [[personal, after_reconstruction, loggia, pane...
# 2   [[personal, panel, furnished], [playground, ta...
# 3   [[personal, brick, cellar, parking_lots], [pla...
# 4   [[collective, loggia, panel, elevator, partly_...
# ..                                                ...
# 56  [[new_building, personal, terrace, brick, cell...
# 57  [[new_building, personal, terrace, brick, cell...
# 58  [[personal, terrace, brick, cellar, elevator, ...
# 59  [[personal, after_reconstruction, brick, eleva...
# 60  [[personal, loggia, panel, elevator, parking_l...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 1   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 2   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 3   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 4   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# ..                                                ...                ...
# 56  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 57  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 58  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 59  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 60  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
#
#     category  has_floor_plan  \
# 0          1               1
# 1          1               0
# 2          1               0
# 3          1               1
# 4          1               1
# ..       ...             ...
# 56         1               1
# 57         1               1
# 58         1               1
# 59         1               0
# 60         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  1293100108
# 1   {'favourite': {'is_favourite': False, '_links'...  ...    37303372
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  2556937292
# 3   {'favourite': {'is_favourite': False, '_links'...  ...   642017628
# 4   {'favourite': {'is_favourite': False, '_links'...  ...  4151944268
# ..                                                ...  ...         ...
# 56  {'favourite': {'is_favourite': False, '_links'...  ...  3780981836
# 57  {'favourite': {'is_favourite': False, '_links'...  ...  2438804556
# 58  {'favourite': {'is_favourite': False, '_links'...  ...  2132161612
# 59  {'favourite': {'is_favourite': False, '_links'...  ...  3592406092
# 60  {'favourite': {'is_favourite': False, '_links'...  ...   236115532
#
#    attractive_offer     price  \
# 0                 0  11538000
# 1                 0   7528000
# 2                 0   3005000
# 3                 0   7808000
# 4                 0   3507000
# ..              ...       ...
# 56                0  15548000
# 57                0   9395000
# 58                0  15578000
# 59                0  14273000
# 60                0   8885000
#
#                                             price_czk  \
# 0   {'value_raw': 11538000, 'unit': '', 'name': 'C...
# 1   {'value_raw': 7528000, 'unit': '', 'name': 'Ce...
# 2   {'value_raw': 3005000, 'unit': '', 'name': 'Ce...
# 3   {'value_raw': 7808000, 'unit': '', 'name': 'Ce...
# 4   {'value_raw': 3507000, 'unit': '', 'name': 'Ce...
# ..                                                ...
# 56  {'value_raw': 15548000, 'unit': '', 'name': 'C...
# 57  {'value_raw': 9395000, 'unit': '', 'name': 'Ce...
# 58  {'value_raw': 15578000, 'unit': '', 'name': 'C...
# 59  {'value_raw': 14273000, 'unit': '', 'name': 'C...
# 60  {'value_raw': 8885000, 'unit': '', 'name': 'Ce...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# ..                                                ...    ...
# 56  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 57  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 58  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 59  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 60  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                       name  region_tip  \
# 0   Prodej bytu 2+kk 74 m²     2449079
# 1    Prodej bytu 3+1 74 m²           0
# 2   Prodej bytu 1+kk 27 m²           0
# 3    Prodej bytu 3+1 82 m²           0
# 4   Prodej bytu 1+kk 34 m²           0
# ..                     ...         ...
# 56  Prodej bytu 3+kk 77 m²           0
# 57  Prodej bytu 2+kk 51 m²           0
# 58  Prodej bytu 3+kk 77 m²           0
# 59  Prodej bytu 2+kk 69 m²           0
# 60  Prodej bytu 4+kk 95 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.07463858339895, 'lon': 14.456021416...               False
# 1   {'lat': 50.12102158339895, 'lon': 14.487859416...               False
# 2   {'lat': 50.04637158339895, 'lon': 14.510415416...               False
# 3   {'lat': 50.04636458339895, 'lon': 14.549230416...               False
# 4   {'lat': 50.11137758339895, 'lon': 14.502495416...               False
# ..                                                ...                 ...
# 56  {'lat': 50.04053558339895, 'lon': 14.341851416...               False
# 57  {'lat': 50.04053558339895, 'lon': 14.341851416...               False
# 58  {'lat': 50.04055458339895, 'lon': 14.341896416...               False
# 59  {'lat': 50.07344058339895, 'lon': 14.462067416...               False
# 60  {'lat': 50.003345583398946, 'lon': 14.41941941...               False
#
# [61 rows x 27 columns]

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
list(range(1,10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def multiple_sreality_requests(start_page,end_page,category_main='flat', category_type='sell', locality_region='Praha'):
    return pd.concat([
        request_sreality(i, category_main=category_main, category_type=category_type, locality_region=locality_region) 
        for i in range(start_page,end_page+1)
    ])

raw = multiple_sreality_requests(0,4)
raw.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18832\43069712.py in <module>
#       5     ])
#       6
# ----> 7 raw = multiple_sreality_requests(0,4)
#       8 raw.head()
#
# ~\AppData\Local\Temp\ipykernel_18832\43069712.py in multiple_sreality_requests(start_page, end_page, category_main, category_type, locality_region)
#       1 def multiple_sreality_requests(start_page,end_page,category_main='flat', category_type='sell', locality_region='Praha'):
# ----> 2     return pd.concat([
#       3         request_sreality(i, category_main=category_main, category_type=category_type, locality_region=locality_region)
#       4         for i in range(start_page,end_page+1)
#       5     ])
#
# c:\Users\frant\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\frant\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#
# c:\Users\frant\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     435                     "only Series and DataFrame objs are valid"
#     436                 )
# --> 437                 raise TypeError(msg)
#     438
#     439             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'dict'>'; only Series and DataFrame objs are valid

# %% [markdown]
# ## Task 2: Cleaning data
#
# ### 2a. Filter columns
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','labelsAll','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %%
def multiple_sreality_requests(start_page,end_page,category_main='flat', category_type='sell', locality_region='Praha'):
    return pd.concat([
        request_sreality(i, category_main=category_main, category_type=category_type, locality_region=locality_region) 
        for i in range(start_page,end_page+1)
    ])

raw = multiple_sreality_requests(0,4)
raw.head()
# Out:
#                                 labelsReleased  has_panorama  \
# 0  [[new_building, balcony, parking_lots], []]             0
# 1                                     [[], []]             0
# 2                                     [[], []]             0
# 3            [[after_reconstruction], [medic]]             0
# 4                         [[balcony], [train]]             0
#
#                                   labels  is_auction  \
# 0        [Novostavba, Balkon, Parkování]       False
# 1                                     []       False
# 2                                     []       False
# 3  [Po rekonstrukci, Lékař 6 min. pěšky]       False
# 4            [Balkon, Vlak 4 min. pěšky]       False
#
#                                            labelsAll  \
# 0  [[new_building, personal, balcony, cellar, ele...
# 1     [[personal, brick, cellar, not_furnished], []]
# 2          [[personal, brick, cellar, elevator], []]
# 3  [[personal, after_reconstruction, brick, cella...
# 4  [[personal, balcony, brick, elevator], [vet, s...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 1  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 2  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 3  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# 4  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
#
#    category  has_floor_plan  \
# 0         1               1
# 1         1               1
# 2         1               0
# 3         1               1
# 4         1               1
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...  1225335884
# 1  {'favourite': {'is_favourite': False, '_links'...  ...   163661388
# 2  {'favourite': {'is_favourite': False, '_links'...  ...  2367013964
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  2045167436
# 4  {'favourite': {'is_favourite': False, '_links'...  ...   739587148
#
#   attractive_offer    price  \
# 0                0  6655000
# 1                0  5966000
# 2                0  9689000
# 3                0  5719000
# 4                0  7025000
#
#                                            price_czk  \
# 0  {'value_raw': 6655000, 'unit': '', 'name': 'Ce...
# 1  {'value_raw': 5966000, 'unit': '', 'name': 'Ce...
# 2  {'value_raw': 9689000, 'unit': '', 'name': 'Ce...
# 3  {'value_raw': 5719000, 'unit': '', 'name': 'Ce...
# 4  {'value_raw': 7025000, 'unit': '', 'name': 'Ce...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                name  region_tip  \
# 0            Prodej bytu 1+kk 45 m²     2449079
# 1            Prodej bytu 2+kk 42 m²           0
# 2            Prodej bytu 2+kk 51 m²           0
# 3             Prodej bytu 2+1 45 m²           0
# 4  Prodej bytu 2+kk 67 m² (Mezonet)           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.07450858339895, 'lon': 14.456531416...               False
# 1  {'lat': 50.04776458339895, 'lon': 14.439760416...               False
# 2  {'lat': 50.09207958339895, 'lon': 14.399234416...               False
# 3  {'lat': 50.09399858339895, 'lon': 14.458484416...               False
# 4  {'lat': 49.973812583398946, 'lon': 14.37474641...                True
#
# [5 rows x 27 columns]

# %%
# Assuming 'raw' is the DataFrame you got from the previous step
filtered_columns = ['locality', 'price', 'name', 'gps', 'hash_id', 'labelsAll', 'exclusively_at_rk']
filtered_df = raw[filtered_columns].copy()

# Display the first few rows of the filtered DataFrame
filtered_df.head()
# Out:
#                locality    price                              name  \
# 0      Praha 3 - Žižkov  6655000            Prodej bytu 1+kk 45 m²
# 1       Praha 4 - Nusle  5966000            Prodej bytu 2+kk 42 m²
# 2     Praha 6 - Dejvice  9689000            Prodej bytu 2+kk 51 m²
# 3  Praha 7 - Holešovice  5719000             Prodej bytu 2+1 45 m²
# 4     Praha 5 - Radotín  7025000  Prodej bytu 2+kk 67 m² (Mezonet)
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.07450858339895, 'lon': 14.456531416...  1225335884
# 1  {'lat': 50.04776458339895, 'lon': 14.439760416...   163661388
# 2  {'lat': 50.09207958339895, 'lon': 14.399234416...  2367013964
# 3  {'lat': 50.09399858339895, 'lon': 14.458484416...  2045167436
# 4  {'lat': 49.973812583398946, 'lon': 14.37474641...   739587148
#
#                                            labelsAll  exclusively_at_rk
# 0  [[new_building, personal, balcony, cellar, ele...                  1
# 1     [[personal, brick, cellar, not_furnished], []]                  0
# 2          [[personal, brick, cellar, elevator], []]                  0
# 3  [[personal, after_reconstruction, brick, cella...                  0
# 4  [[personal, balcony, brick, elevator], [vet, s...                  1

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %%
# Assuming 'raw' is the DataFrame you got from the multiple_sreality_requests function
gps_columns = raw['gps'].apply(pd.Series)
filtered_df['lat'] = gps_columns['lat']
filtered_df['lon'] = gps_columns['lon']

# Display the first few rows of the DataFrame with the new 'lat' and 'lon' columns
filtered_df.head()
# Out:
#                locality    price                              name  \
# 0      Praha 3 - Žižkov  6655000            Prodej bytu 1+kk 45 m²
# 1       Praha 4 - Nusle  5966000            Prodej bytu 2+kk 42 m²
# 2     Praha 6 - Dejvice  9689000            Prodej bytu 2+kk 51 m²
# 3  Praha 7 - Holešovice  5719000             Prodej bytu 2+1 45 m²
# 4     Praha 5 - Radotín  7025000  Prodej bytu 2+kk 67 m² (Mezonet)
#
#       hash_id                                          labelsAll  \
# 0  1225335884  [[new_building, personal, balcony, cellar, ele...
# 1   163661388     [[personal, brick, cellar, not_furnished], []]
# 2  2367013964          [[personal, brick, cellar, elevator], []]
# 3  2045167436  [[personal, after_reconstruction, brick, cella...
# 4   739587148  [[personal, balcony, brick, elevator], [vet, s...
#
#    exclusively_at_rk        lat        lon
# 0                  1  50.074509  14.456531
# 1                  0  50.047765  14.439760
# 2                  0  50.092080  14.399234
# 3                  0  50.093999  14.458484
# 4                  1  49.973813  14.374746

# %% [markdown]
# ### 2b. Get flat type from name
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * try picking third word in string
# * check meaningfulness using `.value_counts()`

# %%
# Assuming 'filtered_df' is the DataFrame you got from the previous steps
filtered_df['flat_type'] = filtered_df['name'].apply(lambda x: x.split()[2])

# Display the distribution of unique flat types
print(filtered_df['flat_type'].value_counts())
# Out:
# 1+kk        30
# 2+kk        29
# 3+kk        15
# 3+1         11
# 2+1          5
# 4+1          5
# 4+kk         5
# 1+1          2
# 5+kk         1
# atypické     1
# 5+1          1
# Name: flat_type, dtype: int64

# %%
def pick_third_word(x):
    return x.split(' ')[2]

clean['name'].apply(pick_third_word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18832\1311470756.py in <module>
#       2     return x.split(' ')[2]
#       3
# ----> 4 clean['name'].apply(pick_third_word)
#
# NameError: name 'clean' is not defined

# %% [markdown]
# ### 2c. Get area from name
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * if this also fail, then you will need to use regex

# %%
filtered_df['area'] = filtered_df['name'].apply(lambda x: x.split()[-2])
print(filtered_df['area'].head())

def extract_area(s):
    words = s.split()
    try:
        idx = words.index('m²')
        return words[idx - 1]
    except ValueError:
        return None

filtered_df['area'] = filtered_df['name'].apply(extract_area)
print(filtered_df['area'].head())

import re

def extract_area_regex(s):
    match = re.search(r'(\d+)\s*m²', s)
    if match:
        return match.group(1)
    return None

filtered_df['area'] = filtered_df['name'].apply(extract_area_regex)
print(filtered_df['area'].head())
# Out:
# 0    45
# 1    42
# 2    51
# 3    45
# 4    m²
# Name: area, dtype: object
# 0    45
# 1    42
# 2    51
# 3    45
# 4    67
# Name: area, dtype: object
# 0    45
# 1    42
# 2    51
# 3    45
# 4    67
# Name: area, dtype: object

# %% [markdown]
# ## Task 3 (Homework): Convert column`labelsAll` into boolean variables
#
# ### Task 3a. Get all possible label names
# * deal with nested-list structure
# * Hint: try sum the whole column to get a nested list of lists.
# * Then flatten the nested list (2D to 1D)
# * Finally keep only unique elements

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 4b. Test existence of label `cellar` for offers
# * again deal with nested list of list structure
# * write generic function `test_existence_of_label(offer_labels,label)`

# %% [markdown]
# ### 4c. Test existence of all possible labels
# * use apply returning series with all labels
